# %% [markdown]
# # CLEANUP
#
# Cleaning the data exported in a .csv file from Manabox

# %%
import pandas as pd
from pathlib import Path

def load_data() -> list[pd.DataFrame]:
    data = Path('../data/raw')
    dfs = [pd.read_csv(file) for file in data.iterdir() if file.is_file() and file.suffix == ".csv"]
    return dfs
    
    
def cleanup (dfs: list[pd.DataFrame]) -> pd.DataFrame:

    cols = ['name', 'quantity', 'rarity', 'set_code', 'set_name', 'foil','scryfall_id', 'condition', 'language']

    cleaned_dfs = []

    for df in dfs:
        df.columns = df.columns.str.lower().str.replace(' ', '_').str.strip()
        df = df[[col for col in cols if col in df.columns]]
        cleaned_dfs.append(df)
        
    cleaned_df = pd.concat(cleaned_dfs, ignore_index=True)
    
    output_dir = Path('data/processed/cleaned_collection.csv')
    output_dir.parent.mkdir(parents=True, exist_ok=True)

    cleaned_df.to_csv(output_dir, index=False)

    return cleaned_df

cleanup(load_data())
# Out:
#                         name  quantity    rarity set_code  \
# 0          Lunar Convocation         1      rare      BLB
# 1     Corpseberry Cultivator         1    common      BLB
# 2          Lunar Convocation         1      rare      BLB
# 3          Stormcatch Mentor         1  uncommon      BLB
# 4            Hunter's Talent         1  uncommon      BLB
# ...                      ...       ...       ...      ...
# 2000                 Goatnap         2  uncommon      ECL
# 2001      Warren Torchmaster         2  uncommon      ECL
# 2002        Blanchwood Armor         2  uncommon      FDN
# 2003           Efflorescence         2    common      SOS
# 2004            Broken Wings         2    common      FDN
#
#                    set_name    foil                           scryfall_id  \
# 0               Bloomburrow    foil  a9ee50d4-c878-457b-964d-29c039ce9852
# 1               Bloomburrow  normal  c911a759-ed7b-452b-88a3-663478357610
# 2               Bloomburrow  normal  a9ee50d4-c878-457b-964d-29c039ce9852
# 3               Bloomburrow  normal  99754055-6d67-4fde-aff3-41f6af6ea764
# 4               Bloomburrow  normal  e9a31863-9649-4a4f-99e4-c93729938bd7
# ...                     ...     ...                                   ...
# 2000        Lorwyn Eclipsed  normal  7d8dbec5-ae71-4f82-898a-b930ec677403
# 2001        Lorwyn Eclipsed  normal  8f067a14-6667-4acf-b33d-e1149188a84d
# 2002            Foundations  normal  1fd7ec1a-dafa-42ca-bc25-f6848fb03f60
# 2003  Secrets of Strixhaven  normal  79b9ace7-eceb-4f97-9ee7-d5ee3e0b3515
# 2004            Foundations  normal  61f9cbeb-cc9c-4562-be65-8a77053faefe
#
#       condition language
# 0     near_mint       en
# 1     near_mint       en
# 2     near_mint       en
# 3     near_mint       en
# 4     near_mint       en
# ...         ...      ...
# 2000  near_mint       en
# 2001  near_mint       pt
# 2002  near_mint       en
# 2003  near_mint       en
# 2004  near_mint       en
#
# [2005 rows x 9 columns]
